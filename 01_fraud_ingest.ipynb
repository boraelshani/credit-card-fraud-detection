# %%
df = spark.read.csv(
    "/Volumes/workspace/default/frauddata/creditcard.csv",
    header=True,
    inferSchema=True
)

df.show(5)
df.printSchema()

# %%
df.write.mode("overwrite").saveAsTable("raw_transactions")
